# %% [markdown]
# <a href="https://colab.research.google.com/github/natzasu13/microexpresion-recognition/blob/smic-microexpresion/Microexpression_recognition_MicroExpSTCNN_SMIC_Maestria_v1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Microexpresion recognition**
# #**SMIC Database**
#
#
#
# **MicroExpSTCNN Model**
#
# Natalia Zartha
# Maestria en Ingenira de Sistemas y Computación, 2021

# %% [markdown]
# ![micro.JPG](data:image/jpeg;base64,...)

# %%
import os
import cv2
import numpy
import imageio
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, precision_recall_curve, roc_curve, auc
from keras.models import Sequential, model_from_json
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution3D, MaxPooling3D
from tensorflow.keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils, generic_utils
from sklearn.model_selection import train_test_split
from keras import backend as K
import sys
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers

K.set_image_data_format('channels_first')

# %% [markdown]
# #Import files from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Load images

# %%
image_rows, image_columns, image_depth = 64, 64, 18
training_list = []
negative_images_count, positive_images_count, surprise_images_count = 0,0,0

CODE_PATH = 'drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC'
SMIC_path = CODE_PATH + '/datasets/SMIC'
HSpath =SMIC_path +'/SMIC_all_cropped/HS/'

rootDirectory = os.listdir(HSpath)
for s in rootDirectory:
    sPath = HSpath + s + "/micro/negative/"
    microPath = os.listdir(sPath)
    for video in microPath:
        videopath = sPath + video
        frames = []
        framelisting = os.listdir(videopath)
        framesCount = image_depth if len(framelisting) > image_depth else 0     
        framerange = [x for x in range(image_depth)]
        if(framesCount != 0):
            for frame in framerange:
                  imagepath = videopath + "/" + framelisting[frame]
                  image = cv2.imread(imagepath)
                  imageresize = cv2.resize(image, (image_rows, image_columns), interpolation = cv2.INTER_AREA)
                  grayimage = cv2.cvtColor(imageresize, cv2.COLOR_BGR2GRAY)
                  frames.append(grayimage)  

            frames = numpy.asarray(frames)
            videoarray = numpy.rollaxis(numpy.rollaxis(frames, 2, 0), 2, 0)            
            training_list.append(videoarray)
            negative_images_count  += 1
          

    sPath = HSpath + s + "/micro/positive/"
    microPath = os.listdir(sPath)
    for video in microPath:
        videopath = sPath + video
        frames = []
        framelisting = os.listdir(videopath)
        framesCount = image_depth if len(framelisting) > image_depth else 0
        framerange = [x for x in range(image_depth)] 
        if(framesCount != 0):
            for frame in framerange:
                  imagepath = videopath + "/" + framelisting[frame]
                  image = cv2.imread(imagepath)
                  imageresize = cv2.resize(image, (image_rows, image_columns), interpolation = cv2.INTER_AREA)
                  grayimage = cv2.cvtColor(imageresize, cv2.COLOR_BGR2GRAY)
                  frames.append(grayimage)                  

            frames = numpy.asarray(frames)
            videoarray = numpy.rollaxis(numpy.rollaxis(frames, 2, 0), 2, 0)            
            training_list.append(videoarray)
            positive_images_count +=1


    sPath = HSpath + s + "/micro/surprise/"
    microPath = os.listdir(sPath)
    for video in microPath:
        videopath = sPath + video
        frames = []
        framelisting = os.listdir(videopath)
        framesCount = image_depth if len(framelisting) > image_depth else 0
        framerange = [x for x in range(image_depth)]
        if(framesCount != 0):
            for frame in framerange:
                  imagepath = videopath + "/" + framelisting[frame]
                  image = cv2.imread(imagepath)
                  imageresize = cv2.resize(image, (image_rows, image_columns), interpolation = cv2.INTER_AREA)
                  grayimage = cv2.cvtColor(imageresize, cv2.COLOR_BGR2GRAY)
                  frames.append(grayimage)                  

            frames = numpy.asarray(frames)
            videoarray = numpy.rollaxis(numpy.rollaxis(frames, 2, 0), 2, 0)            
            training_list.append(videoarray)
            surprise_images_count += 1


    print("negative_images_count", negative_images_count)
    print("positive_images_count", positive_images_count)
    print("surprise_images_count", surprise_images_count)
# Out:
# negative_images_count 3
# positive_images_count 3
# surprise_images_count 1
# negative_images_count 5
# positive_images_count 3
# surprise_images_count 6
# negative_images_count 5
# positive_images_count 4
# surprise_images_count 11
# negative_images_count 6
# positive_images_count 5
# surprise_images_count 13
# negative_images_count 9
# positive_images_count 7
# surprise_images_count 18
# negative_images_count 12
# positive_images_count 9
# surprise_images_count 19
# negative_images_count 12
# positive_images_count 10
# surprise_images_count 20
# negative_images_count 12
# positive_images_count 18
# surprise_images_count 21
# negative_images_count 12
# positive_images_count 28
# surprise_images_count 21
# negative_images_count 13
# positive_images_count 28
# surprise_images_count 22
# negative_images_count 22
# positive_images_count 32
# surprise_images_count 22
# negative_images_count 32
# positive_images_count 36
# surprise_images_count 27
# negative_images_count 52
# positive_images_count 46
# surprise_images_count 33
# negative_images_count 54
# positive_images_count 46
# surprise_images_count 35
# negative_images_count 54
# positive_images_count 47
# surprise_images_count 38
# negative_images_count 66
# positive_images_count 50
# surprise_images_count 43

# %% [markdown]
# #Save the database as a zipped file

# %%
"""
Extract the .zip files into the 'train data' folder.
"""
from zipfile import ZipFile

zip_name = "/content/drive/My Drive/train.zip"
with ZipFile(zip_name, 'r') as zip:
  zip.extractall('train data')
  print("Extracted all sound files into the folder 'train data'")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-b6262ff4f804> in <module>()
#       5
#       6 zip_name = "/content/drive/My Drive/train.zip"
# ----> 7 with ZipFile(zip_name, 'r') as zip:
#       8   zip.extractall('train data')
#       9   print("Extracted all sound files into the folder 'train data'")
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1238             while True:
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#    1242                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/train.zip'

# %% [markdown]
# #Preparate data

# %%
#159 imagenes que se conviernes en escala de gris
#64x64 tamaño
#18 frames 

#negative_images_count 66 
#positive_images_count 50 
#surprise_images_count 43 


training_list = numpy.asarray(training_list)
trainingsamples = len(training_list)

traininglabels = numpy.zeros((trainingsamples, ), dtype = int)

traininglabels[0:66] = 0 #negativepath
traininglabels[66:113] = 1  #positivepath
traininglabels[113:156] = 2  #surprise 

traininglabels = np_utils.to_categorical(traininglabels, 3)

training_data = [training_list, traininglabels]
(trainingframes, traininglabels) = (training_data[0], training_data[1])

training_set = numpy.zeros((trainingsamples, 1, image_rows, image_columns, image_depth))


for h in range(trainingsamples):
    training_set[h][0][:][:][:] = trainingframes[h, :, :, :]


training_set = training_set.astype('float32')
training_set -= numpy.mean(training_set)
training_set /= numpy.max(training_set)

# Save training images and labels in a numpy array
numpy.save(CODE_PATH+'/numpy_training_datasets/microexpstcnn_images.npy', training_set)
numpy.save(CODE_PATH+'/numpy_training_datasets/microexpstcnn_labels.npy', traininglabels)

# Load training images and labels that are stored in numpy array
"""
training_set = numpy.load(CODE_PATH+'/numpy_training_datasets/microexpstcnn_images.npy')
traininglabels =numpy.load(CODE_PATH+'/numpy_training_datasets/microexpstcnn_labels.npy')
"""
# Out:
# "\ntraining_set = numpy.load(CODE_PATH+'/numpy_training_datasets/microexpstcnn_images.npy')\ntraininglabels =numpy.load(CODE_PATH+'/numpy_training_datasets/microexpstcnn_labels.npy')\n"

# %% [markdown]
# #Model

# %%
from keras.layers import GaussianNoise

# MicroExpSTCNN Model
model = Sequential()
model.add(Convolution3D(60, kernel_size=(3, 3, 15), input_shape=(1, image_rows, image_columns, image_depth), activation='relu'))
model.add(MaxPooling3D(pool_size=(3, 3, 3)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, kernel_initializer='normal'))
model.add(Activation('softmax'))
                                               # optimizer = 'adam'
model.compile(loss = 'categorical_crossentropy', optimizer = 'SGD', metrics = ['accuracy'])

model.summary()


filepath=CODE_PATH+"/weights_microexpstcnn/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
######filepath=CODE_PATH+"/weights_microexpstcnn/model_weights.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# Load pre-trained weights
#model.load_weights(CODE_PATH+'/weights_microexpstcnn/weights-improvement-40-0.69.hdf5')
#model.load_weights(CODE_PATH+'/weights_microexpstcnn/weights-improvement-01-1.00.hdf5')

# Spliting the dataset into training and validation sets
train_images, validation_images, train_labels, validation_labels =  train_test_split(training_set, traininglabels, test_size=0.3, random_state=4)


# Save validation set in a numpy array
numpy.save(CODE_PATH+'/numpy_validation_dataset/microexpstcnn_val_images.npy', validation_images)
numpy.save(CODE_PATH+'/numpy_validation_dataset/microexpstcnn_val_labels.npy', validation_labels)

# Load validation set from numpy array
#validation_images = numpy.load(CODE_PATH+'/numpy_validation_dataset/microexpstcnn_val_images.npy')
#validation_labels = numpy.load(CODE_PATH+'/numpy_validation_dataset/microexpstcnn_val_labels.npy')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 60, 62, 62, 4)     8160
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 60, 20, 20, 1)     0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 20, 20, 1)     0
# _________________________________________________________________
# flatten (Flatten)            (None, 24000)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3072128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# _________________________________________________________________
# activation (Activation)      (None, 3)                 0
# =================================================================
# Total params: 3,080,675
# Trainable params: 3,080,675
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Add Callback

# %%
"""
https://www.kaggle.com/moghazy/guide-to-cnns-with-data-augmentation-keras
   # Stop training when `val_loss` is no longer improving
        monitor='val_loss',
        # "no longer improving" being defined as "no better than 1e-2 less"
        min_delta=1e-3,
        # "no longer improving" being further defined as "for at least 2 epochs"
        patience=25,
        verbose=1  
"""
callback = tf.keras.callbacks.EarlyStopping(    
  #monitor='loss', patience=13    
  monitor='val_loss', min_delta=1e-3,patience=25, verbose=1  
    )
#callbacks_list = [callback]

# %% [markdown]
# #Training Model

# %%
hist = model.fit(
    train_images,
    train_labels,
    validation_data = (validation_images, validation_labels), 
    callbacks=callbacks_list, 
    batch_size = 16,
    epochs = 200, 
    shuffle=True)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 30s 103ms/step - loss: 1.1178 - accuracy: 0.3604 - val_loss: 1.0394 - val_accuracy: 0.6458
#
# Epoch 00001: val_accuracy improved from -inf to 0.64583, saving model to drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC/weights_microexpstcnn/weights-improvement-01-0.65.hdf5
# Epoch 2/200
# 7/7 [==============================] - 0s 44ms/step - loss: 1.0664 - accuracy: 0.4234 - val_loss: 1.0330 - val_accuracy: 0.6667
#
# Epoch 00002: val_accuracy improved from 0.64583 to 0.66667, saving model to drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC/weights_microexpstcnn/weights-improvement-02-0.67.hdf5
# Epoch 3/200
# 7/7 [==============================] - 0s 42ms/step - loss: 1.0722 - accuracy: 0.4414 - val_loss: 0.9884 - val_accuracy: 0.6458
#
# Epoch 00003: val_accuracy did not improve from 0.66667
# Epoch 4/200
# 7/7 [==============================] - 0s 41ms/step - loss: 1.0519 - accuracy: 0.4685 - val_loss: 0.9550 - val_accuracy: 0.6042
#
# Epoch 00004: val_accuracy did not improve from 0.66667
# Epoch 5/200
# 7/7 [==============================] - 0s 40ms/step - loss: 1.0365 - accuracy: 0.4054 - val_loss: 0.9316 - val_accuracy: 0.6458
#
# Epoch 00005: val_accuracy did not improve from 0.66667
# Epoch 6/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.9773 - accuracy: 0.5586 - val_loss: 0.9122 - val_accuracy: 0.6667
#
# Epoch 00006: val_accuracy did not improve from 0.66667
# Epoch 7/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.9747 - accuracy: 0.5315 - val_loss: 0.8863 - val_accuracy: 0.7500
#
# Epoch 00007: val_accuracy improved from 0.66667 to 0.75000, saving model to drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC/weights_microexpstcnn/weights-improvement-07-0.75.hdf5
# Epoch 8/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.9744 - accuracy: 0.4865 - val_loss: 0.8927 - val_accuracy: 0.7500
#
# Epoch 00008: val_accuracy did not improve from 0.75000
# Epoch 9/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.9093 - accuracy: 0.6126 - val_loss: 0.8429 - val_accuracy: 0.7500
#
# Epoch 00009: val_accuracy did not improve from 0.75000
# Epoch 10/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.9519 - accuracy: 0.5495 - val_loss: 0.8359 - val_accuracy: 0.7083
#
# Epoch 00010: val_accuracy did not improve from 0.75000
# Epoch 11/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.8529 - accuracy: 0.6486 - val_loss: 0.7938 - val_accuracy: 0.7708
#
# Epoch 00011: val_accuracy improved from 0.75000 to 0.77083, saving model to drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC/weights_microexpstcnn/weights-improvement-11-0.77.hdf5
# Epoch 12/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.9014 - accuracy: 0.5766 - val_loss: 0.7768 - val_accuracy: 0.7917
#
# Epoch 00012: val_accuracy improved from 0.77083 to 0.79167, saving model to drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC/weights_microexpstcnn/weights-improvement-12-0.79.hdf5
# Epoch 13/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.8583 - accuracy: 0.6306 - val_loss: 0.7615 - val_accuracy: 0.7292
#
# Epoch 00013: val_accuracy did not improve from 0.79167
# Epoch 14/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.8582 - accuracy: 0.6216 - val_loss: 0.7669 - val_accuracy: 0.6875
#
# Epoch 00014: val_accuracy did not improve from 0.79167
# Epoch 15/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.7904 - accuracy: 0.6216 - val_loss: 0.7239 - val_accuracy: 0.7500
#
# Epoch 00015: val_accuracy did not improve from 0.79167
# Epoch 16/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.8255 - accuracy: 0.6396 - val_loss: 0.7578 - val_accuracy: 0.6667
#
# Epoch 00016: val_accuracy did not improve from 0.79167
# Epoch 17/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.9221 - accuracy: 0.5586 - val_loss: 0.7115 - val_accuracy: 0.7083
#
# Epoch 00017: val_accuracy did not improve from 0.79167
# Epoch 18/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.8374 - accuracy: 0.6036 - val_loss: 0.7192 - val_accuracy: 0.7083
#
# Epoch 00018: val_accuracy did not improve from 0.79167
# Epoch 19/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.7569 - accuracy: 0.6847 - val_loss: 0.7221 - val_accuracy: 0.6875
#
# Epoch 00019: val_accuracy did not improve from 0.79167
# Epoch 20/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.8220 - accuracy: 0.6396 - val_loss: 0.7268 - val_accuracy: 0.6875
#
# Epoch 00020: val_accuracy did not improve from 0.79167
# Epoch 21/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.8461 - accuracy: 0.5766 - val_loss: 0.6754 - val_accuracy: 0.7917
#
# Epoch 00021: val_accuracy did not improve from 0.79167
# Epoch 22/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.7484 - accuracy: 0.6847 - val_loss: 0.6616 - val_accuracy: 0.7708
#
# Epoch 00022: val_accuracy did not improve from 0.79167
# Epoch 23/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.7820 - accuracy: 0.6577 - val_loss: 0.6345 - val_accuracy: 0.7708
#
# Epoch 00023: val_accuracy did not improve from 0.79167
# Epoch 24/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.7154 - accuracy: 0.6577 - val_loss: 0.7404 - val_accuracy: 0.6875
#
# Epoch 00024: val_accuracy did not improve from 0.79167
# Epoch 25/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.7844 - accuracy: 0.6306 - val_loss: 0.6601 - val_accuracy: 0.7500
#
# Epoch 00025: val_accuracy did not improve from 0.79167
# Epoch 26/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.7295 - accuracy: 0.7027 - val_loss: 0.6359 - val_accuracy: 0.7917
#
# Epoch 00026: val_accuracy did not improve from 0.79167
# Epoch 27/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.6724 - accuracy: 0.7297 - val_loss: 0.5869 - val_accuracy: 0.7917
#
# Epoch 00027: val_accuracy did not improve from 0.79167
# Epoch 28/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.7267 - accuracy: 0.7027 - val_loss: 0.6038 - val_accuracy: 0.7500
#
# Epoch 00028: val_accuracy did not improve from 0.79167
# Epoch 29/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.6805 - accuracy: 0.6577 - val_loss: 0.6441 - val_accuracy: 0.7292
#
# Epoch 00029: val_accuracy did not improve from 0.79167
# Epoch 30/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.6912 - accuracy: 0.7117 - val_loss: 0.6000 - val_accuracy: 0.7500
#
# Epoch 00030: val_accuracy did not improve from 0.79167
# Epoch 31/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.7343 - accuracy: 0.6937 - val_loss: 0.5908 - val_accuracy: 0.7708
#
# Epoch 00031: val_accuracy did not improve from 0.79167
# Epoch 32/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.6049 - accuracy: 0.7477 - val_loss: 0.6058 - val_accuracy: 0.7083
#
# Epoch 00032: val_accuracy did not improve from 0.79167
# Epoch 33/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.6466 - accuracy: 0.7027 - val_loss: 0.6137 - val_accuracy: 0.7292
#
# Epoch 00033: val_accuracy did not improve from 0.79167
# Epoch 34/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.6131 - accuracy: 0.7748 - val_loss: 0.5617 - val_accuracy: 0.7708
#
# Epoch 00034: val_accuracy did not improve from 0.79167
# Epoch 35/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.7284 - accuracy: 0.7207 - val_loss: 0.5800 - val_accuracy: 0.7708
#
# Epoch 00035: val_accuracy did not improve from 0.79167
# Epoch 36/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.6033 - accuracy: 0.7928 - val_loss: 0.5699 - val_accuracy: 0.7292
#
# Epoch 00036: val_accuracy did not improve from 0.79167
# Epoch 37/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.7473 - accuracy: 0.7207 - val_loss: 0.5473 - val_accuracy: 0.7500
#
# Epoch 00037: val_accuracy did not improve from 0.79167
# Epoch 38/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.6175 - accuracy: 0.7207 - val_loss: 0.5821 - val_accuracy: 0.7083
#
# Epoch 00038: val_accuracy did not improve from 0.79167
# Epoch 39/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.5534 - accuracy: 0.7928 - val_loss: 0.5670 - val_accuracy: 0.7292
#
# Epoch 00039: val_accuracy did not improve from 0.79167
# Epoch 40/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6737 - accuracy: 0.6847 - val_loss: 0.6370 - val_accuracy: 0.7083
#
# Epoch 00040: val_accuracy did not improve from 0.79167
# Epoch 41/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.6177 - accuracy: 0.7658 - val_loss: 0.5392 - val_accuracy: 0.7708
#
# Epoch 00041: val_accuracy did not improve from 0.79167
# Epoch 42/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.6299 - accuracy: 0.7207 - val_loss: 0.5495 - val_accuracy: 0.7500
#
# Epoch 00042: val_accuracy did not improve from 0.79167
# Epoch 43/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.5753 - accuracy: 0.6847 - val_loss: 0.5243 - val_accuracy: 0.7292
#
# Epoch 00043: val_accuracy did not improve from 0.79167
# Epoch 44/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.6463 - accuracy: 0.7117 - val_loss: 0.5515 - val_accuracy: 0.7500
#
# Epoch 00044: val_accuracy did not improve from 0.79167
# Epoch 45/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.6143 - accuracy: 0.7477 - val_loss: 0.4957 - val_accuracy: 0.7708
#
# Epoch 00045: val_accuracy did not improve from 0.79167
# Epoch 46/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.6886 - accuracy: 0.6937 - val_loss: 0.5155 - val_accuracy: 0.8333
#
# Epoch 00046: val_accuracy improved from 0.79167 to 0.83333, saving model to drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC/weights_microexpstcnn/weights-improvement-46-0.83.hdf5
# Epoch 47/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.5921 - accuracy: 0.7387 - val_loss: 0.4857 - val_accuracy: 0.7917
#
# Epoch 00047: val_accuracy did not improve from 0.83333
# Epoch 48/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.5717 - accuracy: 0.7387 - val_loss: 0.5410 - val_accuracy: 0.7917
#
# Epoch 00048: val_accuracy did not improve from 0.83333
# Epoch 49/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.4986 - accuracy: 0.8018 - val_loss: 0.4933 - val_accuracy: 0.7917
#
# Epoch 00049: val_accuracy did not improve from 0.83333
# Epoch 50/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6002 - accuracy: 0.7297 - val_loss: 0.4956 - val_accuracy: 0.8125
#
# Epoch 00050: val_accuracy did not improve from 0.83333
# Epoch 51/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6445 - accuracy: 0.7297 - val_loss: 0.5201 - val_accuracy: 0.7708
#
# Epoch 00051: val_accuracy did not improve from 0.83333
# Epoch 52/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.5358 - accuracy: 0.7568 - val_loss: 0.4943 - val_accuracy: 0.7917
#
# Epoch 00052: val_accuracy did not improve from 0.83333
# Epoch 53/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.5744 - accuracy: 0.7658 - val_loss: 0.5223 - val_accuracy: 0.7500
#
# Epoch 00053: val_accuracy did not improve from 0.83333
# Epoch 54/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.5807 - accuracy: 0.7748 - val_loss: 0.4852 - val_accuracy: 0.7917
#
# Epoch 00054: val_accuracy did not improve from 0.83333
# Epoch 55/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6488 - accuracy: 0.6667 - val_loss: 0.4945 - val_accuracy: 0.7500
#
# Epoch 00055: val_accuracy did not improve from 0.83333
# Epoch 56/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.4779 - accuracy: 0.8108 - val_loss: 0.4934 - val_accuracy: 0.7708
#
# Epoch 00056: val_accuracy did not improve from 0.83333
# Epoch 57/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.5112 - accuracy: 0.7658 - val_loss: 0.4912 - val_accuracy: 0.7708
#
# Epoch 00057: val_accuracy did not improve from 0.83333
# Epoch 58/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.5458 - accuracy: 0.8108 - val_loss: 0.4655 - val_accuracy: 0.7917
#
# Epoch 00058: val_accuracy did not improve from 0.83333
# Epoch 59/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.4513 - accuracy: 0.7748 - val_loss: 0.4982 - val_accuracy: 0.7500
#
# Epoch 00059: val_accuracy did not improve from 0.83333
# Epoch 60/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.4843 - accuracy: 0.8018 - val_loss: 0.4972 - val_accuracy: 0.7500
#
# Epoch 00060: val_accuracy did not improve from 0.83333
# Epoch 61/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.5907 - accuracy: 0.7658 - val_loss: 0.4557 - val_accuracy: 0.7917
#
# Epoch 00061: val_accuracy did not improve from 0.83333
# Epoch 62/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.5900 - accuracy: 0.7658 - val_loss: 0.4770 - val_accuracy: 0.7917
#
# Epoch 00062: val_accuracy did not improve from 0.83333
# Epoch 63/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.5792 - accuracy: 0.7297 - val_loss: 0.4593 - val_accuracy: 0.7917
#
# Epoch 00063: val_accuracy did not improve from 0.83333
# Epoch 64/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.5024 - accuracy: 0.8288 - val_loss: 0.4763 - val_accuracy: 0.7500
#
# Epoch 00064: val_accuracy did not improve from 0.83333
# Epoch 65/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.5028 - accuracy: 0.7568 - val_loss: 0.4757 - val_accuracy: 0.7500
#
# Epoch 00065: val_accuracy did not improve from 0.83333
# Epoch 66/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.5208 - accuracy: 0.7297 - val_loss: 0.5017 - val_accuracy: 0.7917
#
# Epoch 00066: val_accuracy did not improve from 0.83333
# Epoch 67/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.5291 - accuracy: 0.7748 - val_loss: 0.4862 - val_accuracy: 0.7500
#
# Epoch 00067: val_accuracy did not improve from 0.83333
# Epoch 68/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4469 - accuracy: 0.8468 - val_loss: 0.4608 - val_accuracy: 0.7500
#
# Epoch 00068: val_accuracy did not improve from 0.83333
# Epoch 69/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.4646 - accuracy: 0.8288 - val_loss: 0.4609 - val_accuracy: 0.7708
#
# Epoch 00069: val_accuracy did not improve from 0.83333
# Epoch 70/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.5167 - accuracy: 0.8018 - val_loss: 0.4681 - val_accuracy: 0.7708
#
# Epoch 00070: val_accuracy did not improve from 0.83333
# Epoch 71/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.5951 - accuracy: 0.7568 - val_loss: 0.4368 - val_accuracy: 0.8125
#
# Epoch 00071: val_accuracy did not improve from 0.83333
# Epoch 72/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.5465 - accuracy: 0.7658 - val_loss: 0.4436 - val_accuracy: 0.8542
#
# Epoch 00072: val_accuracy improved from 0.83333 to 0.85417, saving model to drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC/weights_microexpstcnn/weights-improvement-72-0.85.hdf5
# Epoch 73/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.4551 - accuracy: 0.8288 - val_loss: 0.4511 - val_accuracy: 0.8333
#
# Epoch 00073: val_accuracy did not improve from 0.85417
# Epoch 74/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.5006 - accuracy: 0.8288 - val_loss: 0.4647 - val_accuracy: 0.8125
#
# Epoch 00074: val_accuracy did not improve from 0.85417
# Epoch 75/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.4738 - accuracy: 0.7658 - val_loss: 0.4318 - val_accuracy: 0.7917
#
# Epoch 00075: val_accuracy did not improve from 0.85417
# Epoch 76/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.4300 - accuracy: 0.7748 - val_loss: 0.4480 - val_accuracy: 0.7917
#
# Epoch 00076: val_accuracy did not improve from 0.85417
# Epoch 77/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.4705 - accuracy: 0.7928 - val_loss: 0.4310 - val_accuracy: 0.8333
#
# Epoch 00077: val_accuracy did not improve from 0.85417
# Epoch 78/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4093 - accuracy: 0.8198 - val_loss: 0.4162 - val_accuracy: 0.8333
#
# Epoch 00078: val_accuracy did not improve from 0.85417
# Epoch 79/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3997 - accuracy: 0.8378 - val_loss: 0.4229 - val_accuracy: 0.8333
#
# Epoch 00079: val_accuracy did not improve from 0.85417
# Epoch 80/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4496 - accuracy: 0.8018 - val_loss: 0.4059 - val_accuracy: 0.7917
#
# Epoch 00080: val_accuracy did not improve from 0.85417
# Epoch 81/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.4123 - accuracy: 0.8018 - val_loss: 0.4016 - val_accuracy: 0.8125
#
# Epoch 00081: val_accuracy did not improve from 0.85417
# Epoch 82/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.5272 - accuracy: 0.7568 - val_loss: 0.4383 - val_accuracy: 0.8750
#
# Epoch 00082: val_accuracy improved from 0.85417 to 0.87500, saving model to drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC/weights_microexpstcnn/weights-improvement-82-0.88.hdf5
# Epoch 83/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.4218 - accuracy: 0.8649 - val_loss: 0.4128 - val_accuracy: 0.8750
#
# Epoch 00083: val_accuracy did not improve from 0.87500
# Epoch 84/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.4309 - accuracy: 0.8108 - val_loss: 0.4017 - val_accuracy: 0.8125
#
# Epoch 00084: val_accuracy did not improve from 0.87500
# Epoch 85/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.4108 - accuracy: 0.8108 - val_loss: 0.3948 - val_accuracy: 0.7708
#
# Epoch 00085: val_accuracy did not improve from 0.87500
# Epoch 86/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.4261 - accuracy: 0.8198 - val_loss: 0.4057 - val_accuracy: 0.8542
#
# Epoch 00086: val_accuracy did not improve from 0.87500
# Epoch 87/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.5701 - accuracy: 0.7207 - val_loss: 0.4156 - val_accuracy: 0.8125
#
# Epoch 00087: val_accuracy did not improve from 0.87500
# Epoch 88/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4112 - accuracy: 0.8198 - val_loss: 0.3927 - val_accuracy: 0.8125
#
# Epoch 00088: val_accuracy did not improve from 0.87500
# Epoch 89/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.4222 - accuracy: 0.7748 - val_loss: 0.3978 - val_accuracy: 0.8125
#
# Epoch 00089: val_accuracy did not improve from 0.87500
# Epoch 90/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3898 - accuracy: 0.8468 - val_loss: 0.4280 - val_accuracy: 0.8125
#
# Epoch 00090: val_accuracy did not improve from 0.87500
# Epoch 91/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.5415 - accuracy: 0.7658 - val_loss: 0.4311 - val_accuracy: 0.8125
#
# Epoch 00091: val_accuracy did not improve from 0.87500
# Epoch 92/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.4347 - accuracy: 0.8018 - val_loss: 0.4383 - val_accuracy: 0.7917
#
# Epoch 00092: val_accuracy did not improve from 0.87500
# Epoch 93/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.4409 - accuracy: 0.8288 - val_loss: 0.4312 - val_accuracy: 0.8125
#
# Epoch 00093: val_accuracy did not improve from 0.87500
# Epoch 94/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.4350 - accuracy: 0.8559 - val_loss: 0.4269 - val_accuracy: 0.8125
#
# Epoch 00094: val_accuracy did not improve from 0.87500
# Epoch 95/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.4467 - accuracy: 0.8108 - val_loss: 0.4390 - val_accuracy: 0.8125
#
# Epoch 00095: val_accuracy did not improve from 0.87500
# Epoch 96/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3788 - accuracy: 0.8378 - val_loss: 0.4275 - val_accuracy: 0.7917
#
# Epoch 00096: val_accuracy did not improve from 0.87500
# Epoch 97/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3591 - accuracy: 0.8468 - val_loss: 0.4011 - val_accuracy: 0.7917
#
# Epoch 00097: val_accuracy did not improve from 0.87500
# Epoch 98/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.4470 - accuracy: 0.8288 - val_loss: 0.4074 - val_accuracy: 0.7917
#
# Epoch 00098: val_accuracy did not improve from 0.87500
# Epoch 99/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4115 - accuracy: 0.8468 - val_loss: 0.4138 - val_accuracy: 0.8333
#
# Epoch 00099: val_accuracy did not improve from 0.87500
# Epoch 100/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3954 - accuracy: 0.8108 - val_loss: 0.4260 - val_accuracy: 0.8125
#
# Epoch 00100: val_accuracy did not improve from 0.87500
# Epoch 101/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4086 - accuracy: 0.8288 - val_loss: 0.4359 - val_accuracy: 0.7917
#
# Epoch 00101: val_accuracy did not improve from 0.87500
# Epoch 102/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.4029 - accuracy: 0.7928 - val_loss: 0.3982 - val_accuracy: 0.8750
#
# Epoch 00102: val_accuracy did not improve from 0.87500
# Epoch 103/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3531 - accuracy: 0.8288 - val_loss: 0.4228 - val_accuracy: 0.8125
#
# Epoch 00103: val_accuracy did not improve from 0.87500
# Epoch 104/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.4573 - accuracy: 0.7928 - val_loss: 0.4245 - val_accuracy: 0.7917
#
# Epoch 00104: val_accuracy did not improve from 0.87500
# Epoch 105/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.3887 - accuracy: 0.8288 - val_loss: 0.4106 - val_accuracy: 0.8125
#
# Epoch 00105: val_accuracy did not improve from 0.87500
# Epoch 106/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.4715 - accuracy: 0.8288 - val_loss: 0.3923 - val_accuracy: 0.8125
#
# Epoch 00106: val_accuracy did not improve from 0.87500
# Epoch 107/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4606 - accuracy: 0.8198 - val_loss: 0.3934 - val_accuracy: 0.8333
#
# Epoch 00107: val_accuracy did not improve from 0.87500
# Epoch 108/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3075 - accuracy: 0.8559 - val_loss: 0.3878 - val_accuracy: 0.8333
#
# Epoch 00108: val_accuracy did not improve from 0.87500
# Epoch 109/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3988 - accuracy: 0.8559 - val_loss: 0.3952 - val_accuracy: 0.8333
#
# Epoch 00109: val_accuracy did not improve from 0.87500
# Epoch 110/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3840 - accuracy: 0.8198 - val_loss: 0.3858 - val_accuracy: 0.8125
#
# Epoch 00110: val_accuracy did not improve from 0.87500
# Epoch 111/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.4451 - accuracy: 0.8288 - val_loss: 0.3831 - val_accuracy: 0.8333
#
# Epoch 00111: val_accuracy did not improve from 0.87500
# Epoch 112/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.4181 - accuracy: 0.8018 - val_loss: 0.4107 - val_accuracy: 0.7917
#
# Epoch 00112: val_accuracy did not improve from 0.87500
# Epoch 113/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3984 - accuracy: 0.8288 - val_loss: 0.4045 - val_accuracy: 0.8125
#
# Epoch 00113: val_accuracy did not improve from 0.87500
# Epoch 114/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3855 - accuracy: 0.8198 - val_loss: 0.4206 - val_accuracy: 0.8333
#
# Epoch 00114: val_accuracy did not improve from 0.87500
# Epoch 115/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.3853 - accuracy: 0.8288 - val_loss: 0.3980 - val_accuracy: 0.7917
#
# Epoch 00115: val_accuracy did not improve from 0.87500
# Epoch 116/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3276 - accuracy: 0.8559 - val_loss: 0.3909 - val_accuracy: 0.7917
#
# Epoch 00116: val_accuracy did not improve from 0.87500
# Epoch 117/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3738 - accuracy: 0.8198 - val_loss: 0.3968 - val_accuracy: 0.8542
#
# Epoch 00117: val_accuracy did not improve from 0.87500
# Epoch 118/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3636 - accuracy: 0.8649 - val_loss: 0.3940 - val_accuracy: 0.8333
#
# Epoch 00118: val_accuracy did not improve from 0.87500
# Epoch 119/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.4043 - accuracy: 0.8559 - val_loss: 0.3870 - val_accuracy: 0.8333
#
# Epoch 00119: val_accuracy did not improve from 0.87500
# Epoch 120/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.4668 - accuracy: 0.8198 - val_loss: 0.3804 - val_accuracy: 0.7917
#
# Epoch 00120: val_accuracy did not improve from 0.87500
# Epoch 121/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.4362 - accuracy: 0.8108 - val_loss: 0.3920 - val_accuracy: 0.8333
#
# Epoch 00121: val_accuracy did not improve from 0.87500
# Epoch 122/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3228 - accuracy: 0.8739 - val_loss: 0.3888 - val_accuracy: 0.7917
#
# Epoch 00122: val_accuracy did not improve from 0.87500
# Epoch 123/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3293 - accuracy: 0.8649 - val_loss: 0.3723 - val_accuracy: 0.8333
#
# Epoch 00123: val_accuracy did not improve from 0.87500
# Epoch 124/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3367 - accuracy: 0.8919 - val_loss: 0.3727 - val_accuracy: 0.8333
#
# Epoch 00124: val_accuracy did not improve from 0.87500
# Epoch 125/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.4276 - accuracy: 0.8378 - val_loss: 0.4112 - val_accuracy: 0.8333
#
# Epoch 00125: val_accuracy did not improve from 0.87500
# Epoch 126/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3590 - accuracy: 0.8468 - val_loss: 0.3884 - val_accuracy: 0.8333
#
# Epoch 00126: val_accuracy did not improve from 0.87500
# Epoch 127/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.4061 - accuracy: 0.8198 - val_loss: 0.3770 - val_accuracy: 0.8333
#
# Epoch 00127: val_accuracy did not improve from 0.87500
# Epoch 128/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4477 - accuracy: 0.8198 - val_loss: 0.3885 - val_accuracy: 0.8333
#
# Epoch 00128: val_accuracy did not improve from 0.87500
# Epoch 129/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3693 - accuracy: 0.8378 - val_loss: 0.3850 - val_accuracy: 0.8125
#
# Epoch 00129: val_accuracy did not improve from 0.87500
# Epoch 130/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3965 - accuracy: 0.8198 - val_loss: 0.3770 - val_accuracy: 0.8333
#
# Epoch 00130: val_accuracy did not improve from 0.87500
# Epoch 131/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.4013 - accuracy: 0.8559 - val_loss: 0.3667 - val_accuracy: 0.7917
#
# Epoch 00131: val_accuracy did not improve from 0.87500
# Epoch 132/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3797 - accuracy: 0.8288 - val_loss: 0.3981 - val_accuracy: 0.8333
#
# Epoch 00132: val_accuracy did not improve from 0.87500
# Epoch 133/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3818 - accuracy: 0.8468 - val_loss: 0.3973 - val_accuracy: 0.8125
#
# Epoch 00133: val_accuracy did not improve from 0.87500
# Epoch 134/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.3998 - accuracy: 0.8108 - val_loss: 0.3983 - val_accuracy: 0.8125
#
# Epoch 00134: val_accuracy did not improve from 0.87500
# Epoch 135/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4047 - accuracy: 0.8198 - val_loss: 0.3934 - val_accuracy: 0.8333
#
# Epoch 00135: val_accuracy did not improve from 0.87500
# Epoch 136/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3676 - accuracy: 0.8288 - val_loss: 0.3895 - val_accuracy: 0.8333
#
# Epoch 00136: val_accuracy did not improve from 0.87500
# Epoch 137/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3767 - accuracy: 0.8739 - val_loss: 0.3776 - val_accuracy: 0.8125
#
# Epoch 00137: val_accuracy did not improve from 0.87500
# Epoch 138/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3867 - accuracy: 0.7928 - val_loss: 0.3817 - val_accuracy: 0.8125
#
# Epoch 00138: val_accuracy did not improve from 0.87500
# Epoch 139/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.3067 - accuracy: 0.9009 - val_loss: 0.3829 - val_accuracy: 0.8125
#
# Epoch 00139: val_accuracy did not improve from 0.87500
# Epoch 140/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3578 - accuracy: 0.8649 - val_loss: 0.3755 - val_accuracy: 0.8750
#
# Epoch 00140: val_accuracy did not improve from 0.87500
# Epoch 141/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.3178 - accuracy: 0.8829 - val_loss: 0.3927 - val_accuracy: 0.8333
#
# Epoch 00141: val_accuracy did not improve from 0.87500
# Epoch 142/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3202 - accuracy: 0.8739 - val_loss: 0.3802 - val_accuracy: 0.8125
#
# Epoch 00142: val_accuracy did not improve from 0.87500
# Epoch 143/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.3023 - accuracy: 0.8649 - val_loss: 0.3901 - val_accuracy: 0.8333
#
# Epoch 00143: val_accuracy did not improve from 0.87500
# Epoch 144/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3495 - accuracy: 0.8378 - val_loss: 0.3826 - val_accuracy: 0.8750
#
# Epoch 00144: val_accuracy did not improve from 0.87500
# Epoch 145/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.4293 - accuracy: 0.8018 - val_loss: 0.3773 - val_accuracy: 0.8125
#
# Epoch 00145: val_accuracy did not improve from 0.87500
# Epoch 146/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3218 - accuracy: 0.8649 - val_loss: 0.3816 - val_accuracy: 0.8333
#
# Epoch 00146: val_accuracy did not improve from 0.87500
# Epoch 147/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3176 - accuracy: 0.8559 - val_loss: 0.3740 - val_accuracy: 0.8542
#
# Epoch 00147: val_accuracy did not improve from 0.87500
# Epoch 148/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3341 - accuracy: 0.8739 - val_loss: 0.3816 - val_accuracy: 0.8333
#
# Epoch 00148: val_accuracy did not improve from 0.87500
# Epoch 149/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3618 - accuracy: 0.8468 - val_loss: 0.3752 - val_accuracy: 0.8333
#
# Epoch 00149: val_accuracy did not improve from 0.87500
# Epoch 150/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3146 - accuracy: 0.8829 - val_loss: 0.3842 - val_accuracy: 0.8333
#
# Epoch 00150: val_accuracy did not improve from 0.87500
# Epoch 151/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3153 - accuracy: 0.8829 - val_loss: 0.3871 - val_accuracy: 0.8333
#
# Epoch 00151: val_accuracy did not improve from 0.87500
# Epoch 152/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.4531 - accuracy: 0.8198 - val_loss: 0.3922 - val_accuracy: 0.8125
#
# Epoch 00152: val_accuracy did not improve from 0.87500
# Epoch 153/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.2960 - accuracy: 0.8649 - val_loss: 0.3872 - val_accuracy: 0.8333
#
# Epoch 00153: val_accuracy did not improve from 0.87500
# Epoch 154/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.3454 - accuracy: 0.8559 - val_loss: 0.3745 - val_accuracy: 0.8125
#
# Epoch 00154: val_accuracy did not improve from 0.87500
# Epoch 155/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3809 - accuracy: 0.8198 - val_loss: 0.3606 - val_accuracy: 0.8125
#
# Epoch 00155: val_accuracy did not improve from 0.87500
# Epoch 156/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.3619 - accuracy: 0.8378 - val_loss: 0.3753 - val_accuracy: 0.8542
#
# Epoch 00156: val_accuracy did not improve from 0.87500
# Epoch 157/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.3275 - accuracy: 0.8468 - val_loss: 0.3590 - val_accuracy: 0.8750
#
# Epoch 00157: val_accuracy did not improve from 0.87500
# Epoch 158/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3320 - accuracy: 0.8649 - val_loss: 0.3582 - val_accuracy: 0.8125
#
# Epoch 00158: val_accuracy did not improve from 0.87500
# Epoch 159/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.2902 - accuracy: 0.8649 - val_loss: 0.3560 - val_accuracy: 0.8333
#
# Epoch 00159: val_accuracy did not improve from 0.87500
# Epoch 160/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3281 - accuracy: 0.8649 - val_loss: 0.3991 - val_accuracy: 0.8125
#
# Epoch 00160: val_accuracy did not improve from 0.87500
# Epoch 161/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.3235 - accuracy: 0.8649 - val_loss: 0.3847 - val_accuracy: 0.8333
#
# Epoch 00161: val_accuracy did not improve from 0.87500
# Epoch 162/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3702 - accuracy: 0.8108 - val_loss: 0.3742 - val_accuracy: 0.8750
#
# Epoch 00162: val_accuracy did not improve from 0.87500
# Epoch 163/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.3150 - accuracy: 0.8649 - val_loss: 0.3651 - val_accuracy: 0.8333
#
# Epoch 00163: val_accuracy did not improve from 0.87500
# Epoch 164/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.3420 - accuracy: 0.8378 - val_loss: 0.3805 - val_accuracy: 0.8333
#
# Epoch 00164: val_accuracy did not improve from 0.87500
# Epoch 165/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3388 - accuracy: 0.8468 - val_loss: 0.3666 - val_accuracy: 0.8333
#
# Epoch 00165: val_accuracy did not improve from 0.87500
# Epoch 166/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.2971 - accuracy: 0.8739 - val_loss: 0.3885 - val_accuracy: 0.8542
#
# Epoch 00166: val_accuracy did not improve from 0.87500
# Epoch 167/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.2891 - accuracy: 0.9009 - val_loss: 0.3839 - val_accuracy: 0.8542
#
# Epoch 00167: val_accuracy did not improve from 0.87500
# Epoch 168/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3443 - accuracy: 0.8559 - val_loss: 0.3525 - val_accuracy: 0.8750
#
# Epoch 00168: val_accuracy did not improve from 0.87500
# Epoch 169/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.3755 - accuracy: 0.8108 - val_loss: 0.3609 - val_accuracy: 0.8333
#
# Epoch 00169: val_accuracy did not improve from 0.87500
# Epoch 170/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3825 - accuracy: 0.8288 - val_loss: 0.3545 - val_accuracy: 0.8125
#
# Epoch 00170: val_accuracy did not improve from 0.87500
# Epoch 171/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3369 - accuracy: 0.8559 - val_loss: 0.3455 - val_accuracy: 0.8750
#
# Epoch 00171: val_accuracy did not improve from 0.87500
# Epoch 172/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3372 - accuracy: 0.8468 - val_loss: 0.3439 - val_accuracy: 0.8333
#
# Epoch 00172: val_accuracy did not improve from 0.87500
# Epoch 173/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.3157 - accuracy: 0.8378 - val_loss: 0.3600 - val_accuracy: 0.8750
#
# Epoch 00173: val_accuracy did not improve from 0.87500
# Epoch 174/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3084 - accuracy: 0.8739 - val_loss: 0.3671 - val_accuracy: 0.8958
#
# Epoch 00174: val_accuracy improved from 0.87500 to 0.89583, saving model to drive/MyDrive/MAESTRIA ING DE SISTEMAS/1. MICROEXPRESIONES FACIALES TRABAJO DE GRADO/3. Codigo/microexpresion-recognition-colab/SMIC/weights_microexpstcnn/weights-improvement-174-0.90.hdf5
# Epoch 175/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3866 - accuracy: 0.8018 - val_loss: 0.3577 - val_accuracy: 0.8333
#
# Epoch 00175: val_accuracy did not improve from 0.89583
# Epoch 176/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2628 - accuracy: 0.8649 - val_loss: 0.3708 - val_accuracy: 0.8542
#
# Epoch 00176: val_accuracy did not improve from 0.89583
# Epoch 177/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3090 - accuracy: 0.9009 - val_loss: 0.3606 - val_accuracy: 0.8750
#
# Epoch 00177: val_accuracy did not improve from 0.89583
# Epoch 178/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3075 - accuracy: 0.8739 - val_loss: 0.3580 - val_accuracy: 0.8125
#
# Epoch 00178: val_accuracy did not improve from 0.89583
# Epoch 179/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3386 - accuracy: 0.8378 - val_loss: 0.3762 - val_accuracy: 0.7917
#
# Epoch 00179: val_accuracy did not improve from 0.89583
# Epoch 180/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3714 - accuracy: 0.7568 - val_loss: 0.3761 - val_accuracy: 0.8125
#
# Epoch 00180: val_accuracy did not improve from 0.89583
# Epoch 181/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.2696 - accuracy: 0.8739 - val_loss: 0.3812 - val_accuracy: 0.8125
#
# Epoch 00181: val_accuracy did not improve from 0.89583
# Epoch 182/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3115 - accuracy: 0.8649 - val_loss: 0.3861 - val_accuracy: 0.8333
#
# Epoch 00182: val_accuracy did not improve from 0.89583
# Epoch 183/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3314 - accuracy: 0.8378 - val_loss: 0.3741 - val_accuracy: 0.8542
#
# Epoch 00183: val_accuracy did not improve from 0.89583
# Epoch 184/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3018 - accuracy: 0.8739 - val_loss: 0.3793 - val_accuracy: 0.8750
#
# Epoch 00184: val_accuracy did not improve from 0.89583
# Epoch 185/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2952 - accuracy: 0.8559 - val_loss: 0.3816 - val_accuracy: 0.8750
#
# Epoch 00185: val_accuracy did not improve from 0.89583
# Epoch 186/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3048 - accuracy: 0.8559 - val_loss: 0.3787 - val_accuracy: 0.8750
#
# Epoch 00186: val_accuracy did not improve from 0.89583
# Epoch 187/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.3643 - accuracy: 0.8559 - val_loss: 0.3619 - val_accuracy: 0.8333
#
# Epoch 00187: val_accuracy did not improve from 0.89583
# Epoch 188/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3221 - accuracy: 0.8468 - val_loss: 0.3686 - val_accuracy: 0.8542
#
# Epoch 00188: val_accuracy did not improve from 0.89583
# Epoch 189/200
# 7/7 [==============================] - 0s 48ms/step - loss: 0.3094 - accuracy: 0.8649 - val_loss: 0.3707 - val_accuracy: 0.8333
#
# Epoch 00189: val_accuracy did not improve from 0.89583
# Epoch 190/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.2787 - accuracy: 0.8739 - val_loss: 0.3644 - val_accuracy: 0.8750
#
# Epoch 00190: val_accuracy did not improve from 0.89583
# Epoch 191/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.2995 - accuracy: 0.8649 - val_loss: 0.3544 - val_accuracy: 0.8542
#
# Epoch 00191: val_accuracy did not improve from 0.89583
# Epoch 192/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.3003 - accuracy: 0.8559 - val_loss: 0.3584 - val_accuracy: 0.8750
#
# Epoch 00192: val_accuracy did not improve from 0.89583
# Epoch 193/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.3657 - accuracy: 0.8198 - val_loss: 0.3527 - val_accuracy: 0.8750
#
# Epoch 00193: val_accuracy did not improve from 0.89583
# Epoch 194/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.3095 - accuracy: 0.9009 - val_loss: 0.3480 - val_accuracy: 0.8750
#
# Epoch 00194: val_accuracy did not improve from 0.89583
# Epoch 195/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.2938 - accuracy: 0.8559 - val_loss: 0.3517 - val_accuracy: 0.8542
#
# Epoch 00195: val_accuracy did not improve from 0.89583
# Epoch 196/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.2895 - accuracy: 0.9009 - val_loss: 0.3665 - val_accuracy: 0.8542
#
# Epoch 00196: val_accuracy did not improve from 0.89583
# Epoch 197/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.2529 - accuracy: 0.9099 - val_loss: 0.3589 - val_accuracy: 0.8333
#
# Epoch 00197: val_accuracy did not improve from 0.89583
# Epoch 198/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.2711 - accuracy: 0.8829 - val_loss: 0.3579 - val_accuracy: 0.8333
#
# Epoch 00198: val_accuracy did not improve from 0.89583
# Epoch 199/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.2725 - accuracy: 0.9189 - val_loss: 0.3517 - val_accuracy: 0.8750
#
# Epoch 00199: val_accuracy did not improve from 0.89583
# Epoch 200/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.2799 - accuracy: 0.8919 - val_loss: 0.3677 - val_accuracy: 0.8542
#
# Epoch 00200: val_accuracy did not improve from 0.89583

# %% [markdown]
# #Model accuracy graph

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'], label='accuracy')
plt.plot(hist.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

print("----------Model Evaluate--------")
test_loss, test_acc = model.evaluate(validation_images,  validation_labels, verbose=2)
print("test_acc", test_acc)
print("test_loss", test_loss)



plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'],)
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# ----------Model Evaluate--------
# 2/2 - 0s - loss: 0.3677 - accuracy: 0.8542
# test_acc 0.8541666865348816
# test_loss 0.3677197992801666

# %% [markdown]
# #Data aumentation

# %%
IMG_SIZE = image_columns

resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255)
])

data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.2)
])

"""
data_augmentation =  tf.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(image_rows, image_columns, image_depth)),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2)
  ]
)
"""
# Out:
# '\ndata_augmentation =  tf.keras.Sequential(\n  [\n    layers.experimental.preprocessing.RandomFlip("horizontal", \n                                                 input_shape=(image_rows, image_columns, image_depth)),\n    layers.experimental.preprocessing.RandomRotation(0.2),\n    layers.experimental.preprocessing.RandomZoom(0.2)\n  ]\n)\n'

# %%
from keras.preprocessing.image import ImageDataGenerator

print(train_images.shape)
print(train_labels.shape)
print(validation_images.shape)
print(validation_labels.shape)


#https://hub.packtpub.com/train-convolutional-neural-network-in-keras-improve-with-data-augmentation/
X_train = train_images  #(111, 1, 64, 64, 18)
X_train = train_images[:,:,:,:,0]  #(111, 1, 64, 64)
print(X_train.shape)
y_train = train_labels  #(111, 3)
X_test = validation_images  #(48, 1, 64, 64, 18)
Y_test = validation_labels  #(48, 3)




datagen = ImageDataGenerator(  
    fill_mode='constant', dtype=int        
        #rotation_range=20,
        #width_shift_range=0.02,
        #height_shift_range=0.02,
        #horizontal_flip=True
        
        )


datagen.fill_mode='nearest'
datagen.horizontal_flip=True
datagen.width_shift_range=0.2
datagen.height_shift_range=0.2
datagen.zoom_range=[0.8, 1.2]
datagen.rotation_range=20
datagen.shear_range=10
datagen.brightness_range = [0.75, 1.5]

#datagen.fit(X_train)

#ImageDataGenerator must have 4 dimensions (batch, channel, height, width). 
model.fit_generator(datagen.flow(X_train, y_train, batch_size=100),
                    target_size=(image_columns, image_columns),
                    steps_per_epoch=32,
                    epochs=200,
                    validation_data=(X_test,Y_test),
                    validation_steps=100,
                    callbacks=callbacks_list,
                    verbose=1)

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=10,
    fill_mode='nearest',
    validation_split = 0.3
    #zoom_range=0.15,
    #width_shift_range=0.2,
    #height_shift_range=0.2,
    #shear_range=0.15,
    #horizontal_flip=True
    )

print(train_images.shape)

# %%
X_train = train_images  #(111, 1, 64, 64, 18)
y_train = train_labels  #(111, 3)
X_test = validation_images  #(48, 1, 64, 64, 18)
Y_test = validation_labels  #(48, 3)

#X_train = X_train.reshape(X_train.shape[0], 64, 64 , 1).astype('float32')
#X_test = X_test.reshape(X_test.shape[0], 64, 64 , 1).astype('float32')


#https://www.kaggle.com/moghazy/guide-to-cnns-with-data-augmentation-keras
#datagen.fit(X_train)
#train_generator = datagen.flow(X_train, y_train, batch_size=60, subset='training')
#validation_generator = datagen.flow(X_train, y_train, batch_size=60, subset='validation')


train_datagen = ImageDataGenerator(
        rotation_range=20,
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest")

test_datagen = ImageDataGenerator()
batch_size = 8


train_generator = train_datagen.flow(X_train, y_train,batch_size=batch_size)
valid_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
test_generator = test_datagen.flow(test_data, batch_size=1)


model.fit_generator(train_aug, validation_data=(X_test, Y_test),
 steps_per_epoch=len(X_train),# batch_size,
 epochs=200)





# fits the model on batches with real-time data augmentation:
history = model.fit_generator(generator=train_generator,
                    validation_data=validation_generator,
                    use_multiprocessing=True,
                    steps_per_epoch = 200,
                    validation_steps = 100,
                    epochs = 200,
                    workers=-1)


score = model.evaluate_generator(valid_generator)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

predict = model.predict_generator(test_generator)
# predict the class label
y_classes = predict.argmax(axis=-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-bacc43d7bbee> in <module>()
#       4 Y_test = validation_labels  #(48, 3)
#       5
# ----> 6 X_train = X_train.reshape(X_train.shape[0], 64, 64 , 1)
#       7 X_test = X_test.reshape(X_test.shape[0], 64, 64 , 1)
#       8
#
# ValueError: cannot reshape array of size 8183808 into shape (111,64,64,1)

# %% [markdown]
# #Predictions

# %%
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score, hamming_loss, jaccard_similarity_score, log_loss, zero_one_loss, matthews_corrcoef
# Finding Confusion Matrix using pretrained weights

predictions = model.predict(validation_images)
predictions_labels = numpy.argmax(predictions, axis=1)

validation_labels_y = numpy.argmax(validation_labels, axis=1)

cfm = confusion_matrix(validation_labels_y, predictions_labels)
print("confusion_matrix",cfm )



#precision, recall, thresholds = precision_recall_curve(validation_labels_y,predictions_labels)


#https://www.programcreek.com/python/example/86675/sklearn.metrics.roc_auc_score
#https://aprendeia.com/metricas-de-evaluacion-clasificacion-con-scikit-learn-machine-learning/   PARA DOCUMENTAR LAS METRICAS

print("------------------------------return all metrics results------------------------------")

def evaluation_analysis(true_label,predicted): 
    '''
    return all metrics results
    '''
    print("accuracy (EXACTITUD)",accuracy_score(true_label, predicted))
    print("f1 score macro",f1_score(true_label, predicted, average='macro'))     
    print("f1 score micro",f1_score(true_label, predicted, average='micro'))
    print("precision score (PRESICION)",precision_score(true_label, predicted, average='macro'))
    print("recall score (SENSIBILIDAD)",recall_score(true_label, predicted, average='macro'))
    print("hamming_loss",hamming_loss(true_label, predicted))
    print("classification_report", classification_report(true_label, predicted))
    print("jaccard_similarity_score", jaccard_similarity_score(true_label, predicted))
    #print("log_loss", log_loss(true_label, predicted))
    print("zero_one_loss", zero_one_loss(true_label, predicted))
    #print("AUC&ROC",roc_auc_score(true_label, predicted))
    print("matthews_corrcoef", matthews_corrcoef(true_label, predicted)) 


evaluation_analysis(validation_labels_y,predictions_labels)
# Out:
# confusion_matrix [[24  2  0]
#  [ 0  8  2]
#  [ 0  3  9]]
# ------------------------------return all metrics results------------------------------
# accuracy (EXACTITUD) 0.8541666666666666
# f1 score macro 0.8127536231884057
# f1 score micro 0.8541666666666666
# precision score (PRESICION) 0.8111888111888113
# recall score (SENSIBILIDAD) 0.8243589743589744
# hamming_loss 0.14583333333333334
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        26
#            1       0.62      0.80      0.70        10
#            2       0.82      0.75      0.78        12
#
#     accuracy                           0.85        48
#    macro avg       0.81      0.82      0.81        48
# weighted avg       0.87      0.85      0.86        48
#
# jaccard_similarity_score 0.8541666666666666
# zero_one_loss 0.14583333333333337
# matthews_corrcoef 0.7669724650347257
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:664: FutureWarning: jaccard_similarity_score has been deprecated and replaced with jaccard_score. It will be removed in version 0.23. This implementation has surprising behavior for binary and multiclass classification tasks.
#   FutureWarning)

# %% [markdown]
# #ROC and Precision-Recall curves

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve

X_train = train_images
y_train = train_labels
X_test = validation_images
Y_test = validation_labels

#https://webmonkez.com/questions/1637057/como-encontrar-la-curva-roc-y-la-puntuacion-auc-del-modelo-cnn-keras

prediction = model.predict(validation_images)
y_pred_keras = model.predict(X_test).ravel()

fpr_keras, tpr_keras, thresholds_keras = roc_curve(Y_test.ravel(), y_pred_keras)

from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

import matplotlib.pyplot as plt
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
#plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #Save model as json string

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
